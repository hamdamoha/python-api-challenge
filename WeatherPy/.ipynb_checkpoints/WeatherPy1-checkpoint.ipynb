# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

#save the file
output_data_file = "output_data/cities.csv"

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 600

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    print(city_url)
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"] ["lat"]
        city_lng = city_weather["coord"] ["lon"]
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather ['clouds']['all']
        city_wind =city_weather ['wind']['speed']
        city_country = city_weather ['sys']['country']
        city_date = city_weather ['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

#     # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=atuona
# Processing Record 1 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=coos+bay
# Processing Record 2 of Set 1 | coos bay
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=yellowknife
# Processing Record 3 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=port+alfred
# Processing Record 4 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=paamiut
# Processing Record 5 of Set 1 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=rikitea
# Processing Record 6 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=tuktoyaktuk
# Processing Record 7 of Set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=ushuaia
# Processing Record 8 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=urumqi
# Processing Record 9 of Set 1 | urumqi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=thompson
# Processing Record 10 of Set 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=hirara
# Processing Record 11 of Set 1 | hirara
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=bluff
# Processing Record 12 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=banbury
# Processing Record 13 of Set 1 | banbury
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=faanui
# Processing Record 14 of Set 1 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=comodoro+rivadavia
# Processing Record 15 of Set 1 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=barrow
# Processing Record 16 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=tokur
# Processing Record 17 of Set 1 | tokur
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=amderma
# Processing Record 18 of Set 1 | amderma
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=souillac
# Processing Record 19 of Set 1 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=albany
# Processing Record 20 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=hobart
# Processing Record 21 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=porosozero
# Processing Record 22 of Set 1 | porosozero
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=jamestown
# Processing Record 23 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=chuy
# Processing Record 24 of Set 1 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=oranjemund
# Processing Record 25 of Set 1 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=geraldton
# Processing Record 26 of Set 1 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=cidreira
# Processing Record 27 of Set 1 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=klaksvik
# Processing Record 28 of Set 1 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=borskoye
# Processing Record 29 of Set 1 | borskoye
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=altonia
# Processing Record 30 of Set 1 | altonia
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=qaanaaq
# Processing Record 31 of Set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=bambous+virieux
# Processing Record 32 of Set 1 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=benghazi
# Processing Record 33 of Set 1 | benghazi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=mandalgovi
# Processing Record 34 of Set 1 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=dikson
# Processing Record 35 of Set 1 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=mago
# Processing Record 36 of Set 1 | mago
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=hermanus
# Processing Record 37 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=griffith
# Processing Record 38 of Set 1 | griffith
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=busselton
# Processing Record 39 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=komsomolskiy
# Processing Record 40 of Set 1 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=xichang
# Processing Record 41 of Set 1 | xichang
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=saskylakh
# Processing Record 42 of Set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=kysyl-syr
# Processing Record 43 of Set 1 | kysyl-syr
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=teahupoo
# Processing Record 44 of Set 1 | teahupoo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=jumla
# Processing Record 45 of Set 1 | jumla
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=vaini
# Processing Record 46 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=taolanaro
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=nicoya
# Processing Record 48 of Set 1 | nicoya
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=puerto+ayora
# Processing Record 49 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=avarua
# Processing Record 50 of Set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=dongsheng
# Processing Record 0 of Set 2 | dongsheng
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=longyearbyen
# Processing Record 1 of Set 2 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=maniitsoq
# Processing Record 2 of Set 2 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=hilo
# Processing Record 3 of Set 2 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=chadiza
# Processing Record 4 of Set 2 | chadiza
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=illoqqortoormiut
# Processing Record 5 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=cape+town
# Processing Record 6 of Set 2 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=yumen
# Processing Record 7 of Set 2 | yumen
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=tuggurt
# Processing Record 8 of Set 2 | tuggurt
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=benemerito+de+las+americas
# Processing Record 9 of Set 2 | benemerito de las americas
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=tasiilaq
# Processing Record 10 of Set 2 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=taoudenni
# Processing Record 11 of Set 2 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=bredasdorp
# Processing Record 12 of Set 2 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=clyde+river
# Processing Record 13 of Set 2 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=alofi
# Processing Record 14 of Set 2 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=kismayo
# Processing Record 15 of Set 2 | kismayo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=marcona
# Processing Record 16 of Set 2 | marcona
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=pevek
# Processing Record 17 of Set 2 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=beloha
# Processing Record 18 of Set 2 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=jalu
# Processing Record 19 of Set 2 | jalu
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=barentsburg
# Processing Record 20 of Set 2 | barentsburg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=naze
# Processing Record 21 of Set 2 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=high+level
# Processing Record 22 of Set 2 | high level
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=east+london
# Processing Record 23 of Set 2 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=mar+del+plata
# Processing Record 24 of Set 2 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=saint+george
# Processing Record 25 of Set 2 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=kulhudhuffushi
# Processing Record 26 of Set 2 | kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=castro
# Processing Record 27 of Set 2 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=college
# Processing Record 28 of Set 2 | college
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=uglekamensk
# Processing Record 29 of Set 2 | uglekamensk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=saint-georges
# Processing Record 30 of Set 2 | saint-georges
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=semey
# Processing Record 31 of Set 2 | semey
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=heilbron
# Processing Record 32 of Set 2 | heilbron
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=waddan
# Processing Record 33 of Set 2 | waddan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=kodiak
# Processing Record 34 of Set 2 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=nioki
# Processing Record 35 of Set 2 | nioki
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=belushya+guba
# Processing Record 36 of Set 2 | belushya guba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=luderitz
# Processing Record 37 of Set 2 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=bodden+town
# Processing Record 38 of Set 2 | bodden town
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=zheshart
# Processing Record 39 of Set 2 | zheshart
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=iqaluit
# Processing Record 40 of Set 2 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=hasaki
# Processing Record 41 of Set 2 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=nikolskoye
# Processing Record 42 of Set 2 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=esperance
# Processing Record 43 of Set 2 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=punta+arenas
# Processing Record 44 of Set 2 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=the+valley
# Processing Record 45 of Set 2 | the valley
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=aflu
# Processing Record 46 of Set 2 | aflu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=mazamari
# Processing Record 47 of Set 2 | mazamari
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=new+norfolk
# Processing Record 48 of Set 2 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=kutum
# Processing Record 49 of Set 2 | kutum
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=georgetown
# Processing Record 0 of Set 3 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=sorland
# Processing Record 1 of Set 3 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=kalaleh
# Processing Record 2 of Set 3 | kalaleh
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=maceio
# Processing Record 3 of Set 3 | maceio
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=vostok
# Processing Record 4 of Set 3 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=kapaa
# Processing Record 5 of Set 3 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=olenino
# Processing Record 6 of Set 3 | olenino
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=mahebourg
# Processing Record 7 of Set 3 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=kloulklubed
# Processing Record 8 of Set 3 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=naftah
# Processing Record 9 of Set 3 | naftah
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=rosario+do+sul
# Processing Record 10 of Set 3 | rosario do sul
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=okany
# Processing Record 11 of Set 3 | okany
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=butaritari
# Processing Record 12 of Set 3 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=ponta+do+sol
# Processing Record 13 of Set 3 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=fortuna
# Processing Record 14 of Set 3 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=coahuayana
# Processing Record 15 of Set 3 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=upernavik
# Processing Record 16 of Set 3 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=mataura
# Processing Record 17 of Set 3 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=saint-pierre
# Processing Record 18 of Set 3 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=gornopravdinsk
# Processing Record 19 of Set 3 | gornopravdinsk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=attawapiskat
# Processing Record 20 of Set 3 | attawapiskat
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=saint+anthony
# Processing Record 21 of Set 3 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=salalah
# Processing Record 22 of Set 3 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=agalteca
# Processing Record 23 of Set 3 | agalteca
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=tiksi
# Processing Record 24 of Set 3 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=gwadar
# Processing Record 25 of Set 3 | gwadar
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=mys+shmidta
# Processing Record 26 of Set 3 | mys shmidta
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=sur
# Processing Record 27 of Set 3 | sur
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=kautokeino
# Processing Record 28 of Set 3 | kautokeino
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=bengkulu
# Processing Record 29 of Set 3 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=richards+bay
# Processing Record 30 of Set 3 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=acapulco
# Processing Record 31 of Set 3 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=victoria
# Processing Record 32 of Set 3 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=salamiyah
# Processing Record 33 of Set 3 | salamiyah
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=kapiri+mposhi
# Processing Record 34 of Set 3 | kapiri mposhi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=dangriga
# Processing Record 35 of Set 3 | dangriga
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=okakarara
# Processing Record 36 of Set 3 | okakarara
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=birao
# Processing Record 37 of Set 3 | birao
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=lebu
# Processing Record 38 of Set 3 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=predivinsk
# Processing Record 39 of Set 3 | predivinsk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=chipinge
# Processing Record 40 of Set 3 | chipinge
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=krasnogorodsk
# Processing Record 41 of Set 3 | krasnogorodsk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=bonoua
# Processing Record 42 of Set 3 | bonoua
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=porto+novo
# Processing Record 43 of Set 3 | porto novo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=hithadhoo
# Processing Record 44 of Set 3 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=sitka
# Processing Record 45 of Set 3 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=manado
# Processing Record 46 of Set 3 | manado
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=longlac
# Processing Record 47 of Set 3 | longlac
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=kaitangata
# Processing Record 48 of Set 3 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=okhotsk
# Processing Record 49 of Set 3 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=panaba
# Processing Record 0 of Set 4 | panaba
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=balikpapan
# Processing Record 1 of Set 4 | balikpapan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=inirida
# Processing Record 2 of Set 4 | inirida
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=coihaique
# Processing Record 3 of Set 4 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=padang
# Processing Record 4 of Set 4 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=ancud
# Processing Record 5 of Set 4 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=takoradi
# Processing Record 6 of Set 4 | takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=haibowan
# Processing Record 7 of Set 4 | haibowan
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=port+elizabeth
# Processing Record 8 of Set 4 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=kruisfontein
# Processing Record 9 of Set 4 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=tarakan
# Processing Record 10 of Set 4 | tarakan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=itarema
# Processing Record 11 of Set 4 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=ketchikan
# Processing Record 12 of Set 4 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=otjiwarongo
# Processing Record 13 of Set 4 | otjiwarongo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=kavieng
# Processing Record 14 of Set 4 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=yulara
# Processing Record 15 of Set 4 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=general+pico
# Processing Record 16 of Set 4 | general pico
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=ajijic
# Processing Record 17 of Set 4 | ajijic
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=jaisalmer
# Processing Record 18 of Set 4 | jaisalmer
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=ribeira+grande
# Processing Record 19 of Set 4 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=ede
# Processing Record 20 of Set 4 | ede
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=ewa+beach
# Processing Record 21 of Set 4 | ewa beach
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=calintaan
# Processing Record 22 of Set 4 | calintaan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=felanitx
# Processing Record 23 of Set 4 | felanitx
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=tias
# Processing Record 24 of Set 4 | tias
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=cherskiy
# Processing Record 25 of Set 4 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=lovozero
# Processing Record 26 of Set 4 | lovozero
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=losevo
# Processing Record 27 of Set 4 | losevo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=cayenne
# Processing Record 28 of Set 4 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=amahai
# Processing Record 29 of Set 4 | amahai
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=lichuan
# Processing Record 30 of Set 4 | lichuan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=san+quintin
# Processing Record 31 of Set 4 | san quintin
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=almeirim
# Processing Record 32 of Set 4 | almeirim
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=fengzhen
# Processing Record 33 of Set 4 | fengzhen
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=buchanan
# Processing Record 34 of Set 4 | buchanan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=laguna
# Processing Record 35 of Set 4 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=suntar
# Processing Record 36 of Set 4 | suntar
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=veraval
# Processing Record 37 of Set 4 | veraval
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=pimenta+bueno
# Processing Record 38 of Set 4 | pimenta bueno
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=san+cristobal
# Processing Record 39 of Set 4 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=lokosovo
# Processing Record 40 of Set 4 | lokosovo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=provideniya
# Processing Record 41 of Set 4 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=socota
# Processing Record 42 of Set 4 | socota
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=popondetta
# Processing Record 43 of Set 4 | popondetta
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=pizarro
# Processing Record 44 of Set 4 | pizarro
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=northam
# Processing Record 45 of Set 4 | northam
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=asau
# Processing Record 46 of Set 4 | asau
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=port+lincoln
# Processing Record 47 of Set 4 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=nizhneyansk
# Processing Record 48 of Set 4 | nizhneyansk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=la+asuncion
# Processing Record 49 of Set 4 | la asuncion
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=sept-iles
# Processing Record 0 of Set 5 | sept-iles
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=tsihombe
# Processing Record 1 of Set 5 | tsihombe
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=boueni
# Processing Record 2 of Set 5 | boueni
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=monte+patria
# Processing Record 3 of Set 5 | monte patria
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=batemans+bay
# Processing Record 4 of Set 5 | batemans bay
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=samalaeulu
# Processing Record 5 of Set 5 | samalaeulu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=viedma
# Processing Record 6 of Set 5 | viedma
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=arraial+do+cabo
# Processing Record 7 of Set 5 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=gat
# Processing Record 8 of Set 5 | gat
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=morro+bay
# Processing Record 9 of Set 5 | morro bay
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=rocha
# Processing Record 10 of Set 5 | rocha
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=pousat
# Processing Record 11 of Set 5 | pousat
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=nardaran
# Processing Record 12 of Set 5 | nardaran
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=tigil
# Processing Record 13 of Set 5 | tigil
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=riohacha
# Processing Record 14 of Set 5 | riohacha
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=airai
# Processing Record 15 of Set 5 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=deputatskiy
# Processing Record 16 of Set 5 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=samusu
# Processing Record 17 of Set 5 | samusu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=lompoc
# Processing Record 18 of Set 5 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=vangaindrano
# Processing Record 19 of Set 5 | vangaindrano
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=touros
# Processing Record 20 of Set 5 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=capitan+bado
# Processing Record 21 of Set 5 | capitan bado
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=guerrero+negro
# Processing Record 22 of Set 5 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=bathsheba
# Processing Record 23 of Set 5 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=kumluca
# Processing Record 24 of Set 5 | kumluca
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=quatre+cocos
# Processing Record 25 of Set 5 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=plettenberg+bay
# Processing Record 26 of Set 5 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=digby
# Processing Record 27 of Set 5 | digby
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=azimur
# Processing Record 28 of Set 5 | azimur
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=saint-philippe
# Processing Record 29 of Set 5 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=torbay
# Processing Record 30 of Set 5 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=yerofey+pavlovich
# Processing Record 31 of Set 5 | yerofey pavlovich
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=pacific+grove
# Processing Record 32 of Set 5 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=khatanga
# Processing Record 33 of Set 5 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=carnarvon
# Processing Record 34 of Set 5 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=indianola
# Processing Record 35 of Set 5 | indianola
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=lumphat
# Processing Record 36 of Set 5 | lumphat
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=udachnyy
# Processing Record 37 of Set 5 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=aswan
# Processing Record 38 of Set 5 | aswan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=havoysund
# Processing Record 39 of Set 5 | havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=mitsamiouli
# Processing Record 40 of Set 5 | mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=sentyabrskiy
# Processing Record 41 of Set 5 | sentyabrskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=kaka
# Processing Record 42 of Set 5 | kaka
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=nome
# Processing Record 43 of Set 5 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=severo-kurilsk
# Processing Record 44 of Set 5 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=pascagoula
# Processing Record 45 of Set 5 | pascagoula
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=bubaque
# Processing Record 46 of Set 5 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=berlevag
# Processing Record 47 of Set 5 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=pilar
# Processing Record 48 of Set 5 | pilar
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=pangai
# Processing Record 49 of Set 5 | pangai
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=emba
# Processing Record 0 of Set 6 | emba
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=irbil
# Processing Record 1 of Set 6 | irbil
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=los+llanos+de+aridane
# Processing Record 2 of Set 6 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=yarada
# Processing Record 3 of Set 6 | yarada
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=manga
# Processing Record 4 of Set 6 | manga
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=thinadhoo
# Processing Record 5 of Set 6 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=vaitupu
# Processing Record 6 of Set 6 | vaitupu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=pisco
# Processing Record 7 of Set 6 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=pangnirtung
# Processing Record 8 of Set 6 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=satitoa
# Processing Record 9 of Set 6 | satitoa
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=north+bend
# Processing Record 10 of Set 6 | north bend
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=aquidauana
# Processing Record 11 of Set 6 | aquidauana
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=chokurdakh
# Processing Record 12 of Set 6 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=leningradskiy
# Processing Record 13 of Set 6 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=beringovskiy
# Processing Record 14 of Set 6 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=kokopo
# Processing Record 15 of Set 6 | kokopo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=saint-leu
# Processing Record 16 of Set 6 | saint-leu
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=jalingo
# Processing Record 17 of Set 6 | jalingo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=mersing
# Processing Record 18 of Set 6 | mersing
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=lata
# Processing Record 19 of Set 6 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=erenhot
# Processing Record 20 of Set 6 | erenhot
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=beira
# Processing Record 21 of Set 6 | beira
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=burns+lake
# Processing Record 22 of Set 6 | burns lake
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=katsuura
# Processing Record 23 of Set 6 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=rawah
# Processing Record 24 of Set 6 | rawah
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=sibolga
# Processing Record 25 of Set 6 | sibolga
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=pulandian
# Processing Record 26 of Set 6 | pulandian
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=handwara
# Processing Record 27 of Set 6 | handwara
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=yerbogachen
# Processing Record 28 of Set 6 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=saldanha
# Processing Record 29 of Set 6 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=akropong
# Processing Record 30 of Set 6 | akropong
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=tuatapere
# Processing Record 31 of Set 6 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=tura
# Processing Record 32 of Set 6 | tura
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=otradnoye
# Processing Record 33 of Set 6 | otradnoye
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=constitucion
# Processing Record 34 of Set 6 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=labutta
# Processing Record 35 of Set 6 | labutta
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=bulawayo
# Processing Record 36 of Set 6 | bulawayo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=acri
# Processing Record 37 of Set 6 | acri
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=sao+jose+da+coroa+grande
# Processing Record 38 of Set 6 | sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=caravelas
# Processing Record 39 of Set 6 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=snyder
# Processing Record 40 of Set 6 | snyder
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=cairns
# Processing Record 41 of Set 6 | cairns
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=tabiauea
# Processing Record 42 of Set 6 | tabiauea
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=billings
# Processing Record 43 of Set 6 | billings
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=cam+ranh
# Processing Record 44 of Set 6 | cam ranh
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=qaqortoq
# Processing Record 45 of Set 6 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=flagstaff
# Processing Record 46 of Set 6 | flagstaff
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=bolungarvik
# Processing Record 47 of Set 6 | bolungarvik
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=warqla
# Processing Record 48 of Set 6 | warqla
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=hovd
# Processing Record 49 of Set 6 | hovd
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=boyolangu
# Processing Record 0 of Set 7 | boyolangu
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=dakar
# Processing Record 1 of Set 7 | dakar
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=marzuq
# Processing Record 2 of Set 7 | marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=port+macquarie
# Processing Record 3 of Set 7 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=suphan+buri
# Processing Record 4 of Set 7 | suphan buri
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=vila+velha
# Processing Record 5 of Set 7 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=mount+darwin
# Processing Record 6 of Set 7 | mount darwin
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=lazarev
# Processing Record 7 of Set 7 | lazarev
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=tasbuget
# Processing Record 8 of Set 7 | tasbuget
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=nanortalik
# Processing Record 9 of Set 7 | nanortalik
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=watsa
# Processing Record 47 of Set 10 | watsa
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=novoaleksandrovsk
# Processing Record 48 of Set 10 | novoaleksandrovsk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=manggar
# Processing Record 49 of Set 10 | manggar
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=tilichiki
# Processing Record 0 of Set 11 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=suluq
# Processing Record 1 of Set 11 | suluq
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=port+pirie
# Processing Record 2 of Set 11 | port pirie
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=luba
# Processing Record 3 of Set 11 | luba
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=hambantota
# Processing Record 4 of Set 11 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=nanma
# Processing Record 5 of Set 11 | nanma
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=sangar
# Processing Record 6 of Set 11 | sangar
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=anloga
# Processing Record 7 of Set 11 | anloga
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=torbat-e+jam
# Processing Record 8 of Set 11 | torbat-e jam
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=tual
# Processing Record 9 of Set 11 | tual
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=teknaf
# Processing Record 10 of Set 11 | teknaf
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=meyungs
# Processing Record 11 of Set 11 | meyungs
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=illela
# Processing Record 12 of Set 11 | illela
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=ocos
# Processing Record 13 of Set 11 | ocos
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=bocas+del+toro
# Processing Record 14 of Set 11 | bocas del toro
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=hamilton
# Processing Record 15 of Set 11 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=andros+town
# Processing Record 16 of Set 11 | andros town
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=balkhash
# Processing Record 17 of Set 11 | balkhash
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=palmital
# Processing Record 18 of Set 11 | palmital
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=chore
# Processing Record 19 of Set 11 | chore
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=santa+isabel+do+rio+negro
# Processing Record 20 of Set 11 | santa isabel do rio negro
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=kuressaare
# Processing Record 21 of Set 11 | kuressaare
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=ust-nera
# Processing Record 22 of Set 11 | ust-nera
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=san+pedro
# Processing Record 23 of Set 11 | san pedro
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=denpasar
# Processing Record 24 of Set 11 | denpasar
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=nata
# Processing Record 25 of Set 11 | nata
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=eureka
# Processing Record 26 of Set 11 | eureka
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=umm+lajj
# Processing Record 27 of Set 11 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=cockburn+town
# Processing Record 28 of Set 11 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=shetpe
# Processing Record 29 of Set 11 | shetpe
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=usinsk
# Processing Record 30 of Set 11 | usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=tambul
# Processing Record 31 of Set 11 | tambul
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=villanueva
# Processing Record 32 of Set 11 | villanueva
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=champerico
# Processing Record 33 of Set 11 | champerico
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=mattru
# Processing Record 34 of Set 11 | mattru
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=kyaikto
# Processing Record 35 of Set 11 | kyaikto
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=manikpur
# Processing Record 36 of Set 11 | manikpur
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=mmabatho
# Processing Record 37 of Set 11 | mmabatho
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=hailey
# Processing Record 38 of Set 11 | hailey
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=vanimo
# Processing Record 39 of Set 11 | vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=hudson+bay
# Processing Record 40 of Set 11 | hudson bay
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=saleaula
# Processing Record 41 of Set 11 | saleaula
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=margate
# Processing Record 42 of Set 11 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=dukhovnitskoye
# Processing Record 43 of Set 11 | dukhovnitskoye
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=koroni
# Processing Record 44 of Set 11 | koroni
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=mount+gambier
# Processing Record 45 of Set 11 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=romny
# Processing Record 46 of Set 11 | romny
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=sao+joao+da+barra
# Processing Record 47 of Set 11 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=myaundzha
# Processing Record 48 of Set 11 | myaundzha
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=poshekhonye
# Processing Record 49 of Set 11 | poshekhonye
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=husavik
# Processing Record 0 of Set 12 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=buala
# Processing Record 1 of Set 12 | buala
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=rosa+zarate
# Processing Record 2 of Set 12 | rosa zarate
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=mumford
# Processing Record 3 of Set 12 | mumford
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=toliary
# Processing Record 4 of Set 12 | toliary
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=dhidhdhoo
# Processing Record 5 of Set 12 | dhidhdhoo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=sao+paulo+de+olivenca
# Processing Record 6 of Set 12 | sao paulo de olivenca
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=bojnurd
# Processing Record 7 of Set 12 | bojnurd
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=wanning
# Processing Record 8 of Set 12 | wanning
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=marienburg
# Processing Record 9 of Set 12 | marienburg
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=halalo
# Processing Record 10 of Set 12 | halalo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=murray+bridge
# Processing Record 11 of Set 12 | murray bridge
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=reconquista
# Processing Record 12 of Set 12 | reconquista
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=henderson
# Processing Record 13 of Set 12 | henderson
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=progreso
# Processing Record 14 of Set 12 | progreso
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=florianopolis
# Processing Record 15 of Set 12 | florianopolis
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=allende
# Processing Record 16 of Set 12 | allende
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=willmar
# Processing Record 17 of Set 12 | willmar
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=karratha
# Processing Record 18 of Set 12 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=anadyr
# Processing Record 19 of Set 12 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=hearst
# Processing Record 20 of Set 12 | hearst
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=port+augusta
# Processing Record 21 of Set 12 | port augusta
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=merauke
# Processing Record 22 of Set 12 | merauke
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=aykhal
# Processing Record 23 of Set 12 | aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=marsh+harbour
# Processing Record 24 of Set 12 | marsh harbour
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=rutland
# Processing Record 25 of Set 12 | rutland
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=mayumba
# Processing Record 26 of Set 12 | mayumba
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=nouadhibou
# Processing Record 27 of Set 12 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=mahajanga
# Processing Record 28 of Set 12 | mahajanga
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=umm+bab
# Processing Record 29 of Set 12 | umm bab
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=colares
# Processing Record 30 of Set 12 | colares
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=talnakh
# Processing Record 31 of Set 12 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=ambulu
# Processing Record 32 of Set 12 | ambulu
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=zaton
# Processing Record 33 of Set 12 | zaton
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=aljezur
# Processing Record 34 of Set 12 | aljezur
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=port+hawkesbury
# Processing Record 35 of Set 12 | port hawkesbury
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=balotra
# Processing Record 36 of Set 12 | balotra
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=yuci
# Processing Record 37 of Set 12 | yuci
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=kuah
# Processing Record 38 of Set 12 | kuah
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=taldan
# Processing Record 39 of Set 12 | taldan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=zyryanka
# Processing Record 40 of Set 12 | zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=lae
# Processing Record 41 of Set 12 | lae
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=rockport
# Processing Record 42 of Set 12 | rockport
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=ananas
# Processing Record 43 of Set 12 | ananas
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=haines+junction
# Processing Record 44 of Set 12 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=sumbawa
# Processing Record 45 of Set 12 | sumbawa
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=cervo
# Processing Record 46 of Set 12 | cervo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=oktyabrskiy
# Processing Record 47 of Set 12 | oktyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=waitati
# Processing Record 48 of Set 12 | waitati
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=eaed2dc6f5bcc0a45483c97f87ae6ed9&q=grand-lahou
# Processing Record 49 of Set 12 | grand-lahou
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          556
# Lat           556
# Lng           556
# Max Temp      556
# Humidity      556
# Cloudiness    556
# Wind Speed    556
# Country       556
# Date          556
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       atuona  -9.8000 -139.0333     26.78        79          68        7.94
# 1     coos bay  43.3665 -124.2179      7.95        91         100        4.63
# 2  yellowknife  62.4560 -114.3525    -20.25        65          40        4.63
# 3  port alfred -33.5906   26.8910     18.99        80         100        0.45
# 4      paamiut  61.9940  -49.6678     -5.32        47          15        1.51
#
#   Country        Date
# 0      PF  1680279839
# 1      US  1680279839
# 2      CA  1680279839
# 3      ZA  1680279839
# 4      GL  1680279839

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             atuona  -9.8000 -139.0333     26.78        79          68
# 1           coos bay  43.3665 -124.2179      7.95        91         100
# 2        yellowknife  62.4560 -114.3525    -20.25        65          40
# 3        port alfred -33.5906   26.8910     18.99        80         100
# 4            paamiut  61.9940  -49.6678     -5.32        47          15
#
#          Wind Speed Country        Date
# City_ID
# 0              7.94      PF  1680279839
# 1              4.63      US  1680279839
# 2              4.63      CA  1680279839
# 3              0.45      ZA  1680279839
# 4              1.51      GL  1680279839

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
Latitude = city_data_df["Lat"]
Max_Temp = city_data_df["Max Temp"]
Humidity = city_data_df["Humidity"]
Cloudiness = city_data_df["Cloudiness"]
Wind_Speed = city_data_df["Wind Speed"]

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(Latitude,Max_Temp, label = "City", edgecolor='black')

# Incorporate the other graph properties
plt.title("Weather")
plt.xlabel("Lat")
plt.ylabel("Temp")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(Latitude,Humidity, label = "City", edgecolor='black')


# Incorporate the other graph properties
plt.title("Weather")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(Latitude,Cloudiness, label = "City", edgecolor='black')


# Incorporate the other graph properties
plt.title("Weather")
plt.xlabel("Temp")
plt.ylabel("Cloudiness")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(Latitude,Wind_Speed, label = "City", edgecolor='black')


# Incorporate the other graph properties
plt.title("Weather")
plt.xlabel("Temp")
plt.ylabel("Wind Speed")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression (x_values, y_values, title, coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,coordinates,fontsize=15,color="red")
    plt.xlabel("latitude")
    plt.ylabel("title")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] > 0)]


# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1           coos bay  43.3665 -124.2179      7.95        91         100
# 2        yellowknife  62.4560 -114.3525    -20.25        65          40
# 4            paamiut  61.9940  -49.6678     -5.32        47          15
# 6        tuktoyaktuk  69.4541 -133.0374    -25.00        70          20
# 8             urumqi  43.8010   87.6005      4.53        49          75
#
#          Wind Speed Country        Date
# City_ID
# 1              4.63      US  1680279839
# 2              4.63      CA  1680279839
# 4              1.51      GL  1680279839
# 6              8.75      CA  1680279840
# 8              6.00      CN  1680279731

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[(city_data_df["Lat"] < 0)]


# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             atuona  -9.8000 -139.0333     26.78        79          68
# 3        port alfred -33.5906   26.8910     18.99        80         100
# 5            rikitea -23.1203 -134.9692     25.88        77          85
# 7            ushuaia -54.8000  -68.3000      8.81        61          20
# 11             bluff -46.6000  168.3333     10.06        91          82
#
#          Wind Speed Country        Date
# City_ID
# 0              7.94      PF  1680279839
# 3              0.45      ZA  1680279839
# 5              3.20      PF  1680279839
# 7              1.54      AR  1680279786
# 11             2.92      NZ  1680279840

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (5,-10))

# %%
# Linear regression on Southern Hemisphere

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (-30,10))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
plot_linear_regression(x_values, y_values, "Latitude", (45,15))

# Save the figure
plt.savefig("./output_data/northern_hem_linear_lat_vs_humidity.png", bbox_inches="tight")

#Display
plt.show()

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
plot_linear_regression(x_values, y_values, "Latitude",(-50, 20))

# Save the figure
plt.savefig("./output_data/southern_hem_linear_lat_vs_humudity.png", bbox_inches="tight")

# Display
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** There is no correlation between latitude and humidity for southern hemisphere (0.3). The same applies for northern hemisphere, expect for the higher latitudes, where we can see some correlation (very weak).

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
plot_linear_regression(x_values, y_values, "Latitude", (30, 30))

#Save the fiure
plt.savefig("./output_data/northern_hem_linear_lat_vs_cloudiness.png", bbox_inches="tight")

#Display
plt.show()

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
plot_linear_regression(x_values, y_values, "Latitude",(-45, 60))

# Save the figure
plt.savefig("./output_data/southern_hem_linear_lat_vs_cloudiness.png", bbox_inches="tight")

# Display
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** There is no correlation between latitude and cloudiness for either. Both show scattered values all over the plots.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
plot_linear_regression(x_values, y_values, "Latitude",(10,14))

# Save the figure
plt.savefig("./output_data/northern_hem_linear_lat_vs_wind_speed.png", bbox_inches="tight")

#Display
plt.show()

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
plot_linear_regression(x_values, y_values, "Latitude",(-25, 14))

#Save the figure
plt.savefig("./output_data/southern_hem_linear_lat_vs_wind_speed.png", bbox_inches="tight")

# Display
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** There is no correlation between latitude and wind speed, for both hemispheres. Both show evenly scattered values over the latitudes.
